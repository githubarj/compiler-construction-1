# %% [markdown]
# <a href="https://colab.research.google.com/github/joel-rodgers/compiler-construction/blob/main/Lab_Activity_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GROUP MEMBERS (ICS4C)**
# 1.   122184-Joel Rodgers K'obara
# 2.   120226-Davies Nathan Akidiva
# 3.   115862-Richard Jeremy Githuba
# 4.   121660-Alex Wamai Kariuki
# 5.   120357-Bettyrose Waithera Mburu

# %% [markdown]
# **Lab 4: Understanding Predictive Parsing**

# %% [markdown]
# **Using an example or illustration, explain what is predictive parsing?**

# %% [markdown]
# Predictive Parsing is an effective technique of executing recursive-descent parsing by managing the stack of activation records.
# Predictive Parsers has the following components −
# 1.   Input Buffer − The input buffer includes the string to be parsed followed by an end marker $ to denote the end of the string.
#
# 2.   Stack − It contains a combination of grammar symbols with dollar sign on the bottom of the stack. At the start of Parsing, the stack contains the start symbol of Grammar followed by $.
#
# 3.  Parsing Table − It is a two-dimensional array or Matrix M [A, a] where A is nonterminal and 'a' is a terminal symbol.
#
# 4.  Parsing Program − The parsing program performs some action by comparing the symbol on top of the stack and the current input symbol to be read on the input buffer.
#
# 5.  Actions − Parsing program takes various actions depending upon the symbol on the top of the stack and the current input symbol.

# %% [markdown]
# **Algorithm to construct Predictive Parsing Table**

# %% [markdown]
# Input − Context-Free Grammar G
#
# Output − Predictive Parsing Table M
#
# Method − For the production A → α of Grammar G.
#
# * For each terminal, a in FIRST (𝛼) add A → α to M [A, a].
# * If ε is in FIRST (α), and b is in FOLLOW (A), then add A → α to M[A, b].
# * If ε is in FIRST (α), and $ is in FOLLOW (A), then add A → α to M[A, $$].
# * All remaining entries in Table M are errors.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Steps to perform Predictive Parsing**

# %% [markdown]
# *   Elimination of Left Recursion
# *   Left Factoring
# *   Computation of FIRST & FOLLOW
# *   Construction of Predictive Parsing Table
# *   Parse the Input String

# %% [markdown]
# **What is LL (1) parsing?**

# %% [markdown]
# LL(1) parsing is a top-down parsing method in the syntax analysis phase of compiler design.  Required components for LL(1) parsing are input string, a stack, parsing table for given grammar, and parser.

# %% [markdown]
# **Why do we get the First () and Follow () i.e. what do these two functions Really**
# **Represent?**

# %% [markdown]
# FIRST and FOLLOW are two functions associated with grammar that help us fill in the entries of an M-table.
#
# *   FIRST (α)− It is a function that gives the set of terminals that begin the strings derived from the production rule. It is a set of terminal symbols that begin in strings derived from α.
# *   FOLLOW (α)- It is a set of terminal symbols that appear immediately to the right of α.

# %% [markdown]
# **Benefit of FIRST ( ) and FOLLOW ( )**

# %% [markdown]
# *   It can be used to prove the LL (K) characteristic of grammar.
# *   It can be used to promote in the construction of predictive parsing tables.
# *   It provides selection information for recursive descent parsers.

# %% [markdown]
# **Are there any unique attributes associated with Top-Down parsing?**

# %% [markdown]
# *   Top-Down Parsing is constructed for the grammar if it is free from ambiguity and left recursion.
# *   The average time complexitiy of a Top-Down Parser is O(n^2).
# *   Top-Down Parsing internally uses the left-most derivation.
